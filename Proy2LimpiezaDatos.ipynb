# %% [markdown]
# <a href="https://colab.research.google.com/github/Bootcamp-DA-P3/LimpiezaDatos_MLL_JPG_MAR/blob/main/Proy2LimpiezaDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Procesamiento y limpieza de datos con Python**
#
# En este proyecto cogemos información de un fichero externo para su preparación y limpieza usando las herramientas de Jupyter NoteBook.
# El objetivo es transformar los datos brutos en un dataset estructurado para su análisis posterior.
# Finalmente se entregará un fichero en formato .CSV con el dataset corregido.

# %% [markdown]
# ## Importación.

# %% [markdown]
# Cargamos la información desde un fichero que se encuentra en Google Drive
# 1. Cargamos
# 2. Guardamos la información en un Dataframe

# %% [markdown]
# mportación y exploración inicial, Diagnóstico y limpieza de datos, y Validación y exportación del dataset limpio.

# %%
#Miguel, Anthony, Jesus
# Importamos el fichero .CSV desde google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. importamos el fichero eal dataframe

# %%
#Miguel
import pandas as pd

# !ls "/content/drive/My Drive/Bootcamp"

# df = pd.read_csv('/content/drive/My Drive/Bootcamp/cafe.csv')
# df.head(5)

# !ls "/content/drive/My Drive/Bootcamp"
# Out:
# ls: cannot access '/content/drive/My Drive/Bootcamp': No such file or directory
# ls: cannot access '/content/drive/My Drive/Bootcamp': No such file or directory

# %% [markdown]
# ## Exploración inicial.

# %% [markdown]
# Limpiamos las cul a b c
# 1. rellenas campos vacios

# %% [markdown]
# ## Diagnóstico de datos.

# %% [markdown]
# ## Limpieza de datos.

# %% [markdown]
#  ## Validación.

# %% [markdown]
# ## Exportación del dataset limpio.

# %%
df.to_csv('/content/drive/My Drive/Bootcamp/cafe_clean.csv')
# Out:
# Hola
