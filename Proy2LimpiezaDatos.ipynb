# %% [markdown]
# <a href="https://colab.research.google.com/github/Bootcamp-DA-P3/LimpiezaDatos_MLL_JPG_MAR/blob/main/Proy2LimpiezaDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aqui es el enlace**

# %%
#Miguel, Anthony, Jesus
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. importamos el fichero eal dataframe

# %%
#Miguel
import pandas as pd

# !ls "/content/drive/My Drive/Bootcamp"

# df = pd.read_csv('/content/drive/My Drive/Bootcamp/cafe.csv')
# df.head(5)

# !ls "/content/drive/My Drive/Bootcamp"
# Out:
# ls: cannot access '/content/drive/My Drive/Bootcamp': No such file or directory
# ls: cannot access '/content/drive/My Drive/Bootcamp': No such file or directory

# %% [markdown]
# Limpiamos las cul a b c
# 1. rellenas campos vacios

# %%
#Jesus
 print("Hola")
# Out:
# Hola
